# %% [markdown]
# # Speech Commands
# In this Practical work you will be given voice commands recorded by devices such as Amazon Alexa or Google Echo assistants. The task is to recognize the voice command from the audio signal. The dataset is stored as waveforms, each one being a 1 second file containing one voice command.
#
# ## I. Classification of segmented voice commands
#
# The first step will be to extract speech features, either Melfilterbanks or MFCC. Then you will train different type of classifiers to recognize the spoken voice command from the speech features. These classifiers are a Logistic Regression and a Neural Network. You can change the **Runtime of your colab instance and use a GPU** if you are using Neural Networks.
#
# ### The next block downloads the dataset and extracts it to your Colab instance. RUN ONLY ONCE!

# %%
#!wget http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz
#!rm -rf speech_commands
#!mkdir speech_commands
#!tar -zxf speech_commands_v0.01.tar.gz -C speech_commands

# %% [markdown]
# ### This block installs necessary libraries

# %%
import numpy as np
# !pip install git+https://github.com/bootphon/spectral.git
# !pip install jiwer
import jiwer
import spectral
import librosa
import IPython
import os, glob
import ast
import scipy.io.wavfile as wav
import sklearn
from sklearn.neural_network import MLPClassifier
import time
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
# %matplotlib inline
random.seed(777)
# Out:
# Collecting git+https://github.com/bootphon/spectral.git
#   Cloning https://github.com/bootphon/spectral.git to /tmp/pip-req-build-vwhys7qo
#   Running command git clone -q https://github.com/bootphon/spectral.git /tmp/pip-req-build-vwhys7qo
# Requirement already satisfied (use --upgrade to upgrade): spectral==0.1.7 from git+https://github.com/bootphon/spectral.git in /home/naunauyoh/anaconda3/lib/python3.7/site-packages
# Requirement already satisfied: numpy>=1.6.2 in /home/naunauyoh/anaconda3/lib/python3.7/site-packages (from spectral==0.1.7) (1.17.3)
# Requirement already satisfied: scipy in /home/naunauyoh/anaconda3/lib/python3.7/site-packages (from spectral==0.1.7) (1.4.1)
# Building wheels for collected packages: spectral
#   Building wheel for spectral (setup.py) ... done
#   Created wheel for spectral: filename=spectral-0.1.7-cp37-cp37m-linux_x86_64.whl size=65977 sha256=ce4b16232ddfda2b3ffc392e27221ebb05858c200b35c97c41cad9d583d1eca2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zgvn0mkn/wheels/3c/f2/54/2c50f141f0f420db12bf2c52c419c88500a1c9b848159b269b
# Successfully built spectral
# Requirement already satisfied: jiwer in /home/naunauyoh/anaconda3/lib/python3.7/site-packages (1.3.2)
# Requirement already satisfied: numpy in /home/naunauyoh/anaconda3/lib/python3.7/site-packages (from jiwer) (1.17.3)

# %% [markdown]
# These functions are just utilities that will help facilitate features extraction. Feel free to modify them if you need to, but it is not required.

# %%
def txt2list(filename):
    lines_list = []
    with open(filename, 'r') as txt:
        for line in txt:
            lines_list.append(line.rstrip('\n'))
    return lines_list

def transform_wavs(wavs_list, feature_func):
    features = []
    for wav in wavs_list:
        features.append(feature_func.transform(wav).flatten())
    return features

def pad(features, max_len=1616):
    padded_features =[]
    for feat_file in features:
        max_len = max(max_len, feat_file.shape[0])
    for feat_file in features:
        pad_size = max_len - feat_file.shape[0]
        left_pad = pad_size // 2
        right_pad = pad_size - left_pad
        padded_features.append(np.pad(feat_file, ((left_pad, right_pad),), 'constant', constant_values=(0, 0)))
    return padded_features

# %% [markdown]
# Load the data. In this practical work, you are expected to train your models on the training set and evaluate them on the validation set. When you will get your final best model, report the results on the test set.

# %%
## Loading data
# label_set = ['no', 'yes', 'up', 'right', 'down', 'left', 'one', 'on', 'off', 'stop', 'go']

path_to_wav = './speech_commands/'
directories_speech_commands = os.listdir(path_to_wav)
directories_speech_commands = [x for x in directories_speech_commands if os.path.isdir(os.path.join(path_to_wav,x))]
directories_speech_commands = [x for x in directories_speech_commands if x != '_background_noise_']
directories_speech_commands
label_set = directories_speech_commands
nb_ex_per_class = 1000 # To have balance classes for the NN/Logistic Regression
# Valid set
valid_list = txt2list('./speech_commands/validation_list.txt')
# Test set
test_list = txt2list('./speech_commands/testing_list.txt')

# %%
# Iterate over files
train_wavs = []
train_labels = []

valid_wavs = []
valid_labels = []

test_wavs = []
test_labels = []

start = time.time()

for root, dirs, files in os.walk("speech_commands"):
    if "_background_noise_" in root:
        continue
    for filename in files:
        if not filename.endswith('.wav'):
            continue
        command = root.split("/")[-1]
        if command not in label_set:
            continue
        else:
            label = label_set.index(command)
        full_name = os.path.join(root, filename)
        partial_path = '/'.join([command, filename])
        if partial_path in valid_list and valid_labels.count(label) < nb_ex_per_class//10:
            fs, waveform = wav.read(full_name)
            valid_wavs.append(waveform)
            valid_labels.append(label)
        elif partial_path in test_list and len(test_labels) < 1000:
            fs, waveform = wav.read(full_name)
            test_wavs.append(waveform)
            test_labels.append(label)
        elif train_labels.count(label) < nb_ex_per_class:
            fs, waveform = wav.read(full_name)
            train_wavs.append(waveform)
            train_labels.append(label)
# Print data statistics

print("Train files:" + str(len(train_wavs)))
print("Valid files:" + str(len(valid_wavs)))
print("Test files:" + str(len(test_wavs)))

end = time.time()

print("Time to output features: " + str(end-start))
# Out:
# Train files:30000
# Valid files:3000
# Test files:1000
# Time to output features: 315.9912519454956

# %% [markdown]
# The following cells create feature functions that have a .transform method that takes a waveform as input. You should not change the framerate parameter (the dataset is sampled at 16kHz).
# The other parameters are the following:
# * nfilt = number of mel-filters to average spectrograms
# * ncep = number of cepstral coefficients to use for MFCCs
# * do_dct = True to compute MFCC (otherwise mel-filterbanks are the output)
# * lowerf = lowest frequency spanned by the filters (and that will be taken into account by the features)
# * higherf = highest frequency spanned by the filters
# * alpha = parameter use for the pre-emphasis
# * frate = number of frames per second (1/frate is the stride of the windows in seconds)
# * wlen = length of windows in seconds
# * nfft = number of frequency bins used to compute the spectrogram
# * compression = the final compression performed on the mel-filterbanks (before DCT if you put do_dct=True)
# * do_deltas = compute the first derivatives of MFCC
# * do_deltasdeltas = compute the second derivatives of MFCC

# %%
framerate = 16000

# %% [markdown]
# # Mel-filterbanks function

# %%
melfbanks = spectral.Spectral(nfilt=20,
                    ncep=0,
                    do_dct=False,
                    lowerf=500,
                    upperf=5000,
                    alpha=0.6,
                    fs=framerate,
                    frate=100,
                    wlen=0.035,
                    nfft=512,
                    compression='log',
                    do_deltas=False,
                    do_deltasdeltas=False)

# %% [markdown]
# # Modification Runs

# %%
# Feature Normalization, with the option to do per-channel or across-channel Gaussian Normalization
# We usually save the normalization parameters when normalizing the input parameters


my_mean = None
my_std = None
my_non_zero = None

def chan_normalize(features, across=False, save_params=False):
    global my_mean 
    global my_std    
    global my_non_zero    
        
    if across:
        if my_non_zero is None:
            my_non_zero = np.nonzero(features.std(axis=1))
        features = features.transpose()
    elif my_non_zero is None:
        my_non_zero = np.nonzero(features.std(axis=0))
        
    if my_mean is None or my_std is None:
        my_mean = features[:, my_non_zero].mean(axis=0)
        my_std = features[:, my_non_zero].std(axis=0)
        
    features[:, my_non_zero] = (features[:, my_non_zero] - my_mean ) / my_std
                            
    if across:
        features = features.transpose()
    
    if not save_params:
        my_mean = None
        my_std = None
        my_non_zero = None
        
    return features

# %%
# Function used to run one experiment with various modifiable parameters

def run_experiment(nfilt=20, ncep=8, lowerf=500, upperf=5000, do_deltas=True, 
                   do_deltasdeltas=False, normalize=False, is_across=False,
                  add_noise=False, train_n_limit=None):
    
    if nfilt != 20:
        melfbanks = spectral.Spectral(nfilt=nfilt,
                        ncep=0,
                        do_dct=False,
                        lowerf=500,
                        upperf=5000,
                        alpha=0.6,
                        fs=framerate,
                        frate=100,
                        wlen=0.035,
                        nfft=512,
                        compression='log',
                        do_deltas=False,
                        do_deltasdeltas=False)
        feature_function = melfbanks
    else:
        mfcc = spectral.Spectral(
                        nfilt=nfilt,
                        ncep=ncep,
                        do_dct=True,
                        lowerf=lowerf,
                        upperf=upperf,
                        alpha=0.6,
                        fs=framerate,
                        frate=100,
                        wlen=0.035,
                        nfft=512,
                        compression='log',
                        do_deltas=do_deltas,
                        do_deltasdeltas=do_deltasdeltas,
                    )
        # Choose the feature function
        feature_function = mfcc

    start = time.time()    
    train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
    valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
    test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
    my_train_labels = train_labels
    
    if train_n_limit is not None:
        train_feats = train_feats[:train_n_limit]
        my_train_labels = my_train_labels[:train_n_limit]
    
    if normalize:
        train_feats = chan_normalize(train_feats, across=is_across)
        valid_feats = chan_normalize(valid_feats, across=is_across)
        test_feats = chan_normalize(test_feats, across=is_across)

    if add_noise:    
        noise = np.random.normal(0,1)
        train_feats += noise
        valid_feats += noise
        test_feats += noise

    end = time.time()
    #print("Time to output features: " + str(end-start))
    
    
    neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                   verbose = False, random_state = 777, learning_rate='constant',
                                   learning_rate_init=0.01)
    start = time.time()
    neural_net.fit(train_feats, my_train_labels)
    end = time.time()
    #print("Training time: " + str(end-start))
    
    print("Accuracy on valid set " + str(100*neural_net.score(valid_feats, valid_labels)) + "%")

# %% [markdown]
# # Question 1.1 to 1.4

# %%
# Runs experiments for answering questions 1.1 to 1.4

def run_exp_and_report():
    print("Original Gang")
    run_experiment()
    
    print("LOWER")
    for lowerf in lowerfs:
        print(str(lowerf) + ":")
        run_experiment(lowerf=lowerf)
    print()
    
    print("UPPER")
    for upperf in upperfs:
        print(str(upperf) + ":")
        run_experiment(upperf=upperf)
    print()
    
    print("LOWER/UPPER")
    run_experiment(lowerf=100, upperf=5000)
    run_experiment(lowerf=100, upperf=8000)
    run_experiment(lowerf=0, upperf=8000)
    
    print("n FILTERS")
    for nfilt in nfilts:
        print(str(nfilt) + ":")
        run_experiment(nfilt=nfilt)
    print()
    
    print("n CEPS")
    for ncep in nceps:
        print(str(ncep) + ":")
        run_experiment(ncep=ncep)
    print()
    
    print("Deltas")
    run_experiment(do_deltas=True, do_deltasdeltas=True)
    run_experiment(do_deltas=True, do_deltasdeltas=False)
    run_experiment(do_deltas=False, do_deltasdeltas=True)
    run_experiment(do_deltas=False, do_deltasdeltas=False)
    print()
    
    print("Normalization")
    run_experiment(normalize=True)
    run_experiment(normalize=True, is_across=True)
    print()
    
    print("Noise")
    run_experiment(add_noise=True)

# %%
# Values used for the experiment and call to run experiments

lowerfs = [0, 50, 100, 1000]
upperfs = [2500, 6500, 8000]

nfilts = [5, 10, 15, 30, 50, 100, 200] 
nceps = [2, 4, 16, 32]

run_exp_and_report()
# Out:
# Original Gang
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in ndim(a)
#    3018     try:
# -> 3019         return a.ndim
#    3020     except AttributeError:
#
# AttributeError: 'float' object has no attribute 'ndim'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-66c1cef1a587> in <module>
#       7 nceps = [2, 4, 16, 32]
#       8
# ----> 9 run_exp_and_report()
#
# <ipython-input-10-6035342ba382> in run_exp_and_report()
#       3 def run_exp_and_report():
#       4     print("Original Gang")
# ----> 5     run_experiment()
#       6
#       7     print("LOWER")
#
# <ipython-input-9-74a0cf10f504> in run_experiment(nfilt, ncep, lowerf, upperf, do_deltas, do_deltasdeltas, normalize, is_across, add_noise, train_n_limit)
#      40
#      41     start = time.time()
# ---> 42     train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
#      43     valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
#      44     test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
#
# <ipython-input-3-56c8b290a9b1> in transform_wavs(wavs_list, feature_func)
#       9     features = []
#      10     for wav in wavs_list:
# ---> 11         features.append(feature_func.transform(wav).flatten())
#      12     return features
#      13
#
# ~/anaconda3/lib/python3.7/site-packages/spectral/_spectral.py in transform(self, sig)
#     269                 frame = np.resize(frame, self.wlen_samples)
#     270                 frame[self.wlen_samples:] = 0
# --> 271             spec = self.frame2spec(frame)
#     272             cspec = self.compressor(spec)
#     273             if self.do_dct:
#
# ~/anaconda3/lib/python3.7/site-packages/spectral/_spectral.py in frame2spec(self, frame)
#     289         fft = np.fft.rfft(frame, self.nfft)
#     290         power = fft.real * fft.real + fft.imag * fft.imag
# --> 291         return np.dot(power, self.filters).clip(1e-5, np.inf)
#     292
#     293     def calc_deltas(self, X):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     107             min = -float('inf')
#     108             using_deprecated_nan = True
# --> 109         if _clip_dep_is_scalar_nan(max):
#     110             max = float('inf')
#     111             using_deprecated_nan = True
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _clip_dep_is_scalar_nan(a)
#      64     # guarded to protect circular imports
#      65     from numpy.core.fromnumeric import ndim
# ---> 66     if ndim(a) != 0:
#      67         return False
#      68     try:
#
# <__array_function__ internals> in ndim(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in ndim(a)
#    3018     try:
#    3019         return a.ndim
# -> 3020     except AttributeError:
#    3021         return asarray(a).ndim
#    3022
#
# KeyboardInterrupt:

# %% [markdown]
# # MFCC filter

# %%
mfcc = spectral.Spectral(
                    nfilt=20,
                    ncep=8,
                    do_dct=True,
                    lowerf=500,
                    upperf=5000,
                    alpha=0.6,
                    fs=framerate,
                    frate=100,
                    wlen=0.035,
                    nfft=512,
                    compression='log',
                    do_deltas=True,
                    do_deltasdeltas=False,
                )

# %% [markdown]
# # The following cell generates the features for train, valid and test from the waveforms

# %%
# Choose the feature function
normalize = False
add_noise = False

feature_function = mfcc

start = time.time()
train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))

if normalize:
    is_across = False
    train_feats = chan_normalize(train_feats, across=is_across)
    valid_feats = chan_normalize(valid_feats, across=is_across)
    test_feats = chan_normalize(test_feats, across=is_across)

if add_noise:    
    noise = np.random.normal(0,1)
    train_feats += noise
    valid_feats += noise
    test_feats += noise
    
end = time.time()

print("Time to output features: " + str(end-start))
# Out:
# Time to output features: 275.7146427631378

# %% [markdown]
# # Next cell trains a neural network

# %%
neural_net = MLPClassifier(hidden_layer_sizes=(100,100, 100), validation_fraction = 0.2, early_stopping = False,
                                   verbose = True, random_state = 777, learning_rate='constant',
                                   learning_rate_init=0.01)

start = time.time()
neural_net.fit(train_feats, train_labels)
end = time.time()

print("Training time: " + str(end-start))
# Out:
# Iteration 1, loss = 3.07460005
# Iteration 2, loss = 2.35841961
# Iteration 3, loss = 2.10089666
# Iteration 4, loss = 1.99286565
# Iteration 5, loss = 1.93228563
# Iteration 6, loss = 1.87749517
# Iteration 7, loss = 1.82911714
# Iteration 8, loss = 1.83308535
# Iteration 9, loss = 1.79439954
# Iteration 10, loss = 1.76046498
# Iteration 11, loss = 1.74626673
# Iteration 12, loss = 1.73884120
# Iteration 13, loss = 1.72322684
# Iteration 14, loss = 1.73346224
# Iteration 15, loss = 1.70486647
# Iteration 16, loss = 1.69376913
# Iteration 17, loss = 1.67979547
# Iteration 18, loss = 1.67129953
# Iteration 19, loss = 1.67332137
# Iteration 20, loss = 1.65778430
# Iteration 21, loss = 1.64296431
# Iteration 22, loss = 1.64591767
# Iteration 23, loss = 1.64570798
# Iteration 24, loss = 1.63681295
# Iteration 25, loss = 1.62271820
# Iteration 26, loss = 1.62238300
# Iteration 27, loss = 1.61214596
# Iteration 28, loss = 1.61037283
# Iteration 29, loss = 1.63979647
# Iteration 30, loss = 1.61876430
# Iteration 31, loss = 1.62819838
# Iteration 32, loss = 1.60447012
# Iteration 33, loss = 1.59809373
# Iteration 34, loss = 1.61626344
# Iteration 35, loss = 1.60942361
# Iteration 36, loss = 1.58694246
# Iteration 37, loss = 1.59788551
# Iteration 38, loss = 1.58391406
# Iteration 39, loss = 1.61370691
# Iteration 40, loss = 1.59680540
# Iteration 41, loss = 1.61078443
# Iteration 42, loss = 1.57410469
# Iteration 43, loss = 1.56261804
# Iteration 44, loss = 1.59313382
# Iteration 45, loss = 1.58213266
# Iteration 46, loss = 1.58047303
# Iteration 47, loss = 1.59368923
# Iteration 48, loss = 1.57981712
# Iteration 49, loss = 1.56225817
# Iteration 50, loss = 1.56113984
# Iteration 51, loss = 1.56408106
# Iteration 52, loss = 1.57271174
# Iteration 53, loss = 1.57539469
# Iteration 54, loss = 1.57077615
# Iteration 55, loss = 1.56097321
# Iteration 56, loss = 1.53886741
# Iteration 57, loss = 1.53297944
# Iteration 58, loss = 1.54789506
# Iteration 59, loss = 1.55979878
# Iteration 60, loss = 1.52816434
# Iteration 61, loss = 1.56498050
# Iteration 62, loss = 1.56822077
# Iteration 63, loss = 1.54391960
# Iteration 64, loss = 1.54548149
# Iteration 65, loss = 1.53739483
# Iteration 66, loss = 1.55940290
# Iteration 67, loss = 1.55452865
# Iteration 68, loss = 1.56927855
# Iteration 69, loss = 1.56322177
# Iteration 70, loss = 1.54172493
# Iteration 71, loss = 1.55397891
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 85.87017941474915

# %% [markdown]
# # Evaluate it on the valid set

# %%
print("Accuracy on valid set " + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
# Out:
# Accuracy on valid set 48.43333333333334%

# %% [markdown]
# # Next cell trains a logistic regression on the speech features

# %%
#Logistic regression

# logreg = sklearn.linear_model.LogisticRegression(verbose=1, tol=1e-3, random_state=777) Does not scale
logreg = sklearn.linear_model.SGDClassifier(verbose=0,loss='log')
start = time.time()
logreg.fit(train_feats, train_labels)
end = time.time()
print("Training time: " + str(end-start))
# Out:
# Training time: 767.7582921981812

# %% [markdown]
# # You can now evaluate it on the validation set

# %%
print("Accuracy on valid set " + str(100*logreg.score(valid_feats, valid_labels)) + "%")
# Out:
# Accuracy on valid set 21.833333333333332%

# %% [markdown]
# # Listen to a random waveform from the training set

# %%
random_idx = random.randint(0, len(valid_wavs))
random_wav = valid_wavs[random_idx]
IPython.display.Audio(random_wav, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Visualize mel-filterbanks and MFCC

# %%
plt.imshow(melfbanks.transform(random_wav).transpose())
plt.gca().invert_yaxis()

# %%
plt.imshow(mfcc.transform(random_wav).transpose())
plt.gca().invert_yaxis()

# %% [markdown]
# # See what your classifier has predicted

# %%
print(label_set[neural_net.predict(valid_feats[random_idx][np.newaxis])[0]])
# Out:
# off

# %% [markdown]
# # Question 1.6: Implementing the best data preprocessing and the best model

# %%
# Modified MFCC using the best found configuration

mfcc = spectral.Spectral(
                    nfilt=20,
                    ncep=4,
                    do_dct=True,
                    lowerf=100,
                    upperf=6500,
                    alpha=0.6,
                    fs=framerate,
                    frate=100,
                    wlen=0.035,
                    nfft=512,
                    compression='log',
                    do_deltas=False,
                    do_deltasdeltas=False,
                )

# %%
# Create the Dataset and normalize 

feature_function = mfcc

start = time.time()
train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))

train_feats = chan_normalize(train_feats, save_params=True)
valid_feats = chan_normalize(valid_feats, save_params=True)
test_feats = chan_normalize(test_feats, save_params=True)
end = time.time()

print("Time to output features: " + str(end-start))
# Out:
# Time to output features: 237.9965467453003

# %%
my_neural_net = MLPClassifier(hidden_layer_sizes=(300,300,300), validation_fraction = 0.1, early_stopping = False,
                                   verbose = False, random_state = 777, learning_rate='constant',
                                   learning_rate_init=0.001)

start = time.time()
my_neural_net.fit(train_feats, train_labels)
end = time.time()

print("Training time: " + str(end-start))
# Out:
# Training time: 312.1398000717163

# %%
print("Accuracy on valid set " + str(100*my_neural_net.score(valid_feats, valid_labels)) + "%")
# Out:
# Accuracy on valid set 71.1%

# %%
def draw_conf_mat(m):
    df_cm = pd.DataFrame(m, label_set, label_set)
    plt.figure(figsize=(30,30))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt="d") # font size

    plt.show()

# %%
draw_conf_mat(confusion_matrix(valid_labels, my_neural_net.predict(valid_feats)))

# %%
draw_conf_mat(confusion_matrix(train_labels, my_neural_net.predict(train_feats)))

# %% [markdown]
# # What you are expected to do in this first part
# The first part of the TP above contains the different blocks that allow you to train speech commands recognizers. The results provided with the features and classifiers above are far from optimal. Indeed, the parameters for the speech features are poorly chosen.
#
# <!-- You are expected to explore various ways to improve their performance. Here are the main things to try:
# * The parameters of the speech features such as the min/max frequency or window size are poorly chosen, look inside the resources mentioned in the class to find the best parameters for mel-filterbanks and MFCC.
# * The logistic regression can be regularized in different ways (by controlling the C parameter) and you can try to find the best one
# * The neural net proposed is a shallow neural net, far from the best you can train. You should try bigger, deeper architectures, different types of regularization, activation functions, learning rate and so on
# * A standard way of improving generalization is to do mean-variance normalization on your data set. This is done by computing the mean and variance of each feature dimension on the entire training set, and then use it to normalize train, valid and test set
# * The dataset provides noises samples, either artificial (pink, white noise) or real (dishes, bike) in the folder _background_noise. You can try augmenting your dataset by adding noise to the waveforms before computing the features
# * The model is only trained on 300 examples per class, if your hardware allows it, try training on more examples
# * Feel free to also experiment with different classifiers -->
#
# * **Question 1.1**: Study the influence of the frequency range, hyper-parameter for the MFCC, on the validation performance. Choose only one model for this study. Does it concord with what we know about human speech characteristics (see material chap 7.5 Jurafsky ed 2) and sampling limitations of a continuous signal?
# * **Question 1.2**: Study the influence of the number of filters for the mel-log filterbanks and the number of cepstral coefficient for the MFCC, on the validation performance. Choose only one model for this study.
# Interpret this result with what you saw in class.
# * **Question 1.3**: Study the influence of the delta and delta_delta for the MFCC, on the validation performance. Choose only one model for this study.
# Interpret and comment this result.
# * **Question 1.4**: There are also other choices that influence the performance. Study the influence of the normalization after processing the features (per-channel and across channel normalization), the addition of noise, the training size. You can study other augmentation/pre-processing techniques. Focus on one model for this study. Interpret the results for each technique you studied.
# * **Question 1.5**: Study the influence on the performance of the model choices and their hyper-parameters. You can add other models of your choice. Focus on one type of features and one of the configurations based on previous questions. Comment your results.
# * **Question 1.6**: Based on the study on the validation set for the different precedent questions, report the performance for the test set for your best configuration. Feel free to run more experiments. Comment on the results (best model, best features, pre-processing). **Analyze the classes that are the most difficult to recognize**. You can try to push the performance and justify these new choices. The **grade will not depend on the performance of the final system**, but on how you experimented, tried different ideas, and comment on them.
#
#
# [Documentation for logistic regression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)
#
# [Documentation for neural network](http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)

# %% [markdown]
# ## II. Classification of segmented voice commands
#
# ### Prediction of Sequences
# In the second part of the practical work, you are now given a new dataset composed of commands from the same dataset as the first part. This dataset is still composed of audio signal, but of variable lengths.
#
# We denote by $X_{i=1...M}$  input sequence of spoken words, and the goal is to find the most likely sequence of words $W_{i=1...T}$.
#
#
# $ \operatorname*{argmax}_W P(W|X) \approx P(X|W) P(W)   $
#
#
# You saw in class that estimate $P(X|W)$ is the acoustic model part and $P(W)$ is the language model part.
#
# Solving this $argmax$ problem is a **search** problem.  It can be solved with dynamic programming with the [Viterbi algorithm](https://en.wikipedia.org/wiki/Viterbi_algorithm) or with heuristics such as [beam-search](https://en.wikipedia.org/wiki/Beam_search) techniques.
#
# Usually, we have $M>>T$, however in this case, to simplify the practical work, we have $M==T$, and use the posterior from your best classifier of the previous part.
#
# In our case , the acoustic model is taken from the discriminator trained in the first part. Therefore, we can model differently the acoustic model.
#
# $  P(X_i|W_i)  \propto P_{\text{discriminator single word}}(W_i|X_i)  $
#
# **Question 2.1**: Can you point which line in the code above approximated the prior probability of each word $W_i$ to be equal?
#
# ### Evalution with Word Error Rate
# To evaluate the performance of all your decoding strategies, we will use the **Word Error Rate**. It uses dynamic programming to align and compare the hypothesis and reference sequences. There are three type of errors under consideration: Insertion, Deletion and Substitution.
#
#  $WER = 100.\frac{S+D+I}{N}\%$
#
# - S is the total number of substitutions
# - D is the total number of deletions
# - I is the total number of insertions
# - N is the number of words in the reference sentence
#
# **Question 2.2**: Is it possible that WER<0? and WER>100?

# %%
#!wget https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/train_sequence_list.txt 
#!wget https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/test_sequence_list.txt 


path_to_wavs = './speech_commands/'
train_sequence_list = [ast.literal_eval(ex) for ex in txt2list('./train_sequence_list.txt') ]
test_sequence_list = [ast.literal_eval(ex) for ex in txt2list('./test_sequence_list.txt') ]

def generate_wav_from_list_sequence(generated_list_sequence): 
    wavs = np.array([])
    for command in generated_list_sequence[1:]:
        wav_name = os.path.join((path_to_wavs),command[1])
        sample_rate, signal = wav.read(wav_name)
        wavs = np.append(wavs,signal)
    return wavs


# Again warning do not forget to change your pad function according to your choice of input features
  
def generate_posteriors_from_list_sequence(generated_list_sequence, model_predict_proba_function, feature_func): 
    posteriors = []
    inputs = []
    for command in generated_list_sequence[1:]:
        wav_name = os.path.join((path_to_wavs),command[1])
        sample_rate, signal = wav.read(wav_name)
        features_input = np.asarray(pad(transform_wavs([signal], feature_function)))
        inputs.append(features_input)
    
    inputs = np.concatenate(inputs, axis=0)
    inputs = chan_normalize(inputs)
    
    for features_input in inputs:
        posterior = model_predict_proba_function(features_input.reshape(-1, 1616))
        posteriors.append(posterior)
    
    posteriors = np.array(posteriors).reshape(-1,len(label_set))
    return posteriors

example_sequence = train_sequence_list[10]
sequence_wav  = generate_wav_from_list_sequence(example_sequence)

#IPython.display.Audio(sequence_wav, rate=16000)

# %% [markdown]
# ### 1. Independent inputs
# #### Greedy search
#
# You will find below an implementation of a greedy decoder assuming full independance between spoken word commands without the alignement problem (each input is matched with one single output).
#
# We use a model from the previous part, **up to you** to use another one to improve the overall performance.

# %%
example_sequence = train_sequence_list[10]

posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(example_sequence, my_neural_net.predict_proba, mfcc))

list_plots = plt.plot(['Word_'+str(el) for el in range(posteriors_neural_mfcc.shape[0])],posteriors_neural_mfcc)
plt.legend(list_plots, label_set, loc="upper left", bbox_to_anchor=(1,1), ncol=6)
plt.ylabel('Posterior activations')
plt.title('Neural network activations with bad MFCCs')
plt.show()


def greedy_decoder(data):
    predicted_sequence = [np.argmax(s) for s in data]
    predicted_sequence = [label_set[el] for el in predicted_sequence]
    return predicted_sequence

def sequence_format_to_text(sentence):
    return [el[0] for el in sentence[1:]]

predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
print('True sentence: ', ' '.join(sequence_format_to_text(example_sequence)))
print('Predicted sentence with greedy search: ', ' '.join(predicted_sequence))
print('WER: ',jiwer.wer(' '.join(sequence_format_to_text(example_sequence)),' '.join(predicted_sequence)))
# Out:
# True sentence:  go marvin one right stop
# Predicted sentence with greedy search:  eight marvin bed right stop
# WER:  0.4

# %% [markdown]
# **Question 2.3**: Can you detail the computations of the WER for the example above?

# %%
# Evaluation of WER for the Greedy Search decoding

greedy_train_hypothesis = []
train_reference = []

# EVALUATION on the full train set takes too much time, so you should evaluate on a subset
for sentence in  np.random.choice(train_sequence_list, 300, replace=False):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
    greedy_train_hypothesis.append(' '.join(predicted_sequence))
    train_reference.append(' '.join(sequence_format_to_text(sentence)))
    
    
greedy_test_hypothesis = []
test_reference = []
for idx, sentence in enumerate(test_sequence_list):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
    greedy_test_hypothesis.append(' '.join(predicted_sequence))
    test_reference.append(' '.join(sequence_format_to_text(sentence)))


start = time.time()
print('Subset Train WER: ',jiwer.wer(train_reference, greedy_train_hypothesis))
print('Test WER: ',jiwer.wer(test_reference, greedy_test_hypothesis))

end = time.time()

print("Evaluation time: " + str(end-start))
# Out:
# Subset Train WER:  0.714828897338403
# Test WER:  0.69880174291939
# Evaluation time: 51.57394003868103

# %% [markdown]
# You will notice with greedy search and without language model, the train WER and test WER are approximately the same.

# %% [markdown]
# ### Inject Language Models in the path scoring
#
# Now, you will incorporate higher information, to improve on the simple classifier that you implemented above. You need to model the transition states $i\rightarrow j$.
#
# #### N-gram model
# You need to estimate and build now this transition matrix. You are only allowed to use the training sequence set to build the language model.
# You can refer to the class to have some ideas, or this paper:
#
# [The Application of Hidden Markov Models in Speech Recognition](https://s3.amazonaws.com/academia.edu.documents/40150101/The_Application_of_Hidden_Markov_Models_20151118-22759-1ab3mz1.pdf?AWSAccessKeyId=AKIAIWOWYYGZ2Y53UL3A&Expires=1549387878&Signature=Q%2FQiFLEgWJAvttO1LbP%2Fkb2OGaw%3D&response-content-disposition=inline%3B%20filename%3DThe_Application_of_Hidden_Markov_Models.pdf) part 2.4
#
# **Question 2.4**: Write the Bigram approximation formula of the language model
#
# **Question 2.5**: Explain briefly your implementation choices
#
# **Question 2.6**: What are the advantages and drawbacks to increase the N ?

# %%
# Build HERE the transition matrix with Bi-gram modelling. You can also do an implementation with bigger N.

def trans_mat_bigram(n_classes):
    result = np.zeros((n_classes +1, n_classes + 1)) #Adding the <start> and <end> tokens 
    
    result += 1 # Laplace Smoothing
    
    for train_sequence in train_sequence_list:
        for i in range(1, len(train_sequence) - 1):
            if i == 1:
                row = -1
                col = label_set.index(train_sequence[i][0])
                result[row, col] +=1
            if i == len(train_sequence) - 2:
                row = label_set.index(train_sequence[i][0])
                col = -1
                result[row, col] +=1
                
                
            ngram = train_sequence[i][0]
            word = train_sequence[i+1][0]
            row = label_set.index(ngram)
            col = label_set.index(word)
            
            result[row, col] += 1
    
    non_zero, _ = np.nonzero(result.sum(axis=1, keepdims=True))
    result[non_zero] = result[non_zero]/result[non_zero].sum(axis=1, keepdims=True)
    
    return result


bigram_mat = trans_mat_bigram(30)

# %%
def plot_bigram(mat):
    df = pd.DataFrame(mat, label_set + ["<start>"], label_set + ["<end>"])
    plt.figure(figsize=(30,30))
    sn.set(font_scale=1.4) # for label size
    hm = sn.heatmap(df, annot_kws={"size": 16}, annot=True,  fmt="0.2f")
    hm.set(xlabel="w_k", ylabel="w_k-1")

plot_bigram(bigram_mat)

# %% [markdown]
# ## Beam-Search
# Based on your transition matrix, your best discriminator, implement the Beam-Search algorithm.
#
# **Question 2.7**: What are the time and memory complexity of the Beam search algorithm?

# %%
# Beam-search decoder
# BELOW IMPLEMENT YOUR BEAM_SEARCH algorithm

extended_label_set = label_set + ["<start>"]

def beam_search_decoder(data,transition_matrix, beam_size=5):
    current_paths = [[[-1],0]]
    for s in data:
        candidate_paths = []
        for path in current_paths:
            seq, score = path
            last_word = seq[-1]
            for idx, next_word_prediction in enumerate(s): 
                if last_word == -1:
                    last_word = transition_matrix.shape[0] - 1
                candidate = [seq + [idx], 
                            score + transition_matrix[last_word, idx] * next_word_prediction]
                candidate_paths.append(candidate)
        candidate_paths.sort(key=lambda x: x[1], reverse=True)
        current_paths = candidate_paths[:beam_size]
            
            
    current_paths.sort(key=lambda x: x[1], reverse=True)
    predicted_sequence = [label_set[x] for x in current_paths[0][0][1:]]
    return predicted_sequence

beam_search_decoder(posteriors_neural_mfcc, bigram_mat)
# Out:
# ['stop', 'house', 'four', 'left', 'stop']

# %%
# Evaluation of WER for the Beam Search decoding

beam_train_hypothesis = []
train_reference = []

# EVALUATION on the full train set takes too much time, so you should evaluate on a subset
for sentence in  np.random.choice(train_sequence_list, 300, replace=False):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = beam_search_decoder(posteriors_neural_mfcc, bigram_mat)
    beam_train_hypothesis.append(' '.join(predicted_sequence))
    train_reference.append(' '.join(sequence_format_to_text(sentence)))
    
    
beam_test_hypothesis = []
test_reference = []
for idx, sentence in enumerate(test_sequence_list):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = beam_search_decoder(posteriors_neural_mfcc, bigram_mat)
    beam_test_hypothesis.append(' '.join(predicted_sequence))
    test_reference.append(' '.join(sequence_format_to_text(sentence)))


start = time.time()
print('Subset Train WER: ',jiwer.wer(train_reference, beam_train_hypothesis))
print('Test WER: ',jiwer.wer(test_reference, beam_test_hypothesis))

end = time.time()

print("Evaluation time: " + str(end-start))
# Out:
# Subset Train WER:  0.6201508620689655
# Test WER:  0.6263616557734205
# Evaluation time: 52.8035614490509

# %% [markdown]
# ## Dynamic progamming with the Viterbi algorithm
# **Question 2.8**: What is the relationship between the probability to be in state  𝑗  at step  𝑘 , and the probabilities to be in state  𝑗′  at step  𝑘−1 ? What are the final time and memory complexity of the Viterbi algorithm?
#
# Based on your transition matrix, your best discriminator, implement now the Viterbi algorithm.

# %%
# Viterbi decoder
# BELOW IMPLEMENT YOUR viterbi algorithm

def viterbi_decoder(data,transition_matrix):
    T = data.shape[0]
    K = 30
    path = np.zeros(T, dtype=int)
    T1 = np.zeros((T, K))
    T2 = np.zeros((T, K))
    
    T1[0, :] = np.log(transition_matrix[-1, :-1] + 0.0000001)

    for t in range(1, T):
        for q in range(K):
            
            T1[t, q] = np.max([
                T1[t - 1, k] + 
                np.log(transition_matrix[k, q] * data[t, q] + 0.00001)
                for k in range(K)
            ])
            T2[t, q] = np.argmax([
                T1[t - 1, k] + np.log(transition_matrix[k, q] * data[t, q] + 0.00001)
                for k in range(K)
            ])

    path[T-1] = np.argmax(T1[T-1,:])
    for t in range(T-2, -1, -1):
        path[t] = T2[t + 1, path[t + 1]]

    return [label_set[el] for el in path]

viterbi_decoder(posteriors_neural_mfcc, bigram_mat)
# Out:
# ['happy', 'house', 'yes', 'nine', 'cat']

# %%
# Evaluation of WER for the Viterbi decoding

viterbi_train_hypothesis = []
train_reference = []

# EVALUATION on the full train set takes too much time, so you should evaluate on a subset
for sentence in  np.random.choice(train_sequence_list, 300, replace=False):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = viterbi_decoder(posteriors_neural_mfcc, bigram_mat)
    viterbi_train_hypothesis.append(' '.join(predicted_sequence))
    train_reference.append(' '.join(sequence_format_to_text(sentence)))
    
viterbi_test_hypothesis = []
test_reference = []
for idx, sentence in enumerate(test_sequence_list):
    posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, my_neural_net.predict_proba, mfcc))
    predicted_sequence = viterbi_decoder(posteriors_neural_mfcc, bigram_mat)
    viterbi_test_hypothesis.append(' '.join(predicted_sequence))
    test_reference.append(' '.join(sequence_format_to_text(sentence)))

start = time.time()
print('Subset Train WER: ',jiwer.wer(train_reference, viterbi_train_hypothesis))
print('Test WER: ',jiwer.wer(test_reference, viterbi_test_hypothesis))

end = time.time()

print("Evaluation time: " + str(end-start))
# Out:
# Subset Train WER:  0.6332599118942731
# Test WER:  0.6127450980392157
# Evaluation time: 50.8389151096344

# %% [markdown]
# # Results for decoding algorithms
#
# In your report for this practical work, you should examine your experiments: the different strategies with  the different implementation choices you made and the various parameters.
#
# **Question 2.9** Compare the performance of the Greedy, Beam-search and Viterbi algorithm: In theory which one is the best and why? What are the results in practice? Comment on the results

# %% [markdown]
# **Question 2.10**: Can you spot systematic errors due to language model you derived from the training sequences? Provide us some of these errors.

# %%
# Looking at systematic and recurring errors due to the language model

for idx, truth in enumerate(test_reference[:200]):
    print("TRUTH:  ", truth)
    print("Greedy: ", greedy_test_hypothesis[idx])
    print("Beam:   ", beam_test_hypothesis[idx])
    print("Viterbi:", viterbi_test_hypothesis[idx])
    print()
# Out:
# TRUTH:   go sheila two up three up one right stop
# Greedy:  go five house house tree five down left stop
# Beam:    go six house off tree five down left stop
# Viterbi: go five house happy tree five down left stop
#
# TRUTH:   happy bird on happy bird wow
# Greedy:  left nine happy left nine wow
# Beam:    stop nine two left stop wow
# Viterbi: go nine happy stop nine wow
#
# TRUTH:   happy house off happy bird no
# Greedy:  happy house five happy down four
# Beam:    happy house nine happy sheila four
# Viterbi: happy house on happy down four
#
# TRUTH:   cat on cat no
# Greedy:  cat nine cat down
# Beam:    cat nine cat down
# Viterbi: go nine cat down
#
# TRUTH:   go sheila zero left stop
# Greedy:  house zero down left wow
# Beam:    house zero down nine wow
# Viterbi: go zero down tree wow
#
# TRUTH:   go marvin two up three right zero down stop
# Greedy:  cat left bed cat happy cat zero down yes
# Beam:    zero left bed cat happy cat four down yes
# Viterbi: go happy tree on happy cat zero down yes
#
# TRUTH:   happy tree on happy cat no
# Greedy:  happy five seven happy cat go
# Beam:    happy nine on happy cat go
# Viterbi: go five on happy cat go
#
# TRUTH:   happy cat off happy cat yes
# Greedy:  off dog five off dog stop
# Beam:    bed dog five off up stop
# Viterbi: go dog five bed dog stop
#
# TRUTH:   go sheila zero up zero down stop
# Greedy:  up four left up three happy zero
# Beam:    dog four left up three down zero
# Viterbi: go four left up three marvin zero
#
# TRUTH:   happy house on happy house wow
# Greedy:  happy house nine happy house nine
# Beam:    happy house on happy house nine
# Viterbi: happy house nine happy house nine
#
# TRUTH:   happy cat on happy tree no
# Greedy:  right cat stop right eight cat
# Beam:    cat cat five right eight cat
# Viterbi: happy cat stop right eight cat
#
# TRUTH:   go sheila zero right stop
# Greedy:  house zero zero left stop
# Beam:    house marvin zero left stop
# Viterbi: go marvin zero left stop
#
# TRUTH:   happy tree on happy tree wow
# Greedy:  up bed down up bed go
# Beam:    stop bed two up bed go
# Viterbi: go bed two up bed go
#
# TRUTH:   go marvin one down three right zero left stop
# Greedy:  four wow five dog right stop zero go two
# Beam:    bird wow five five right stop zero down two
# Viterbi: tree wow five dog right stop zero marvin two
#
# TRUTH:   go marvin zero left five left zero left stop
# Greedy:  go left cat up five left zero left stop
# Beam:    go marvin zero up five left zero left stop
# Viterbi: go marvin one up five left zero left stop
#
# TRUTH:   go marvin zero right two up five right three down stop
# Greedy:  happy four down nine left no stop stop three wow stop
# Beam:    happy four down five left down stop sheila three down stop
# Viterbi: go four down five left stop stop stop three wow stop
#
# TRUTH:   go marvin one left zero up stop
# Greedy:  go one down nine zero house stop
# Beam:    go four down marvin zero down stop
# Viterbi: go one down nine zero down stop
#
# TRUTH:   go sheila three down stop
# Greedy:  four four go marvin left
# Beam:    sheila four go marvin left
# Viterbi: go four go marvin left
#
# TRUTH:   happy tree on happy cat wow
# Greedy:  happy happy stop happy cat go
# Beam:    happy down stop happy cat go
# Viterbi: go down stop happy cat go
#
# TRUTH:   happy cat on happy cat no
# Greedy:  happy stop go happy stop four
# Beam:    happy stop go left stop four
# Viterbi: go stop go down stop four
#
# TRUTH:   happy house off happy cat wow
# Greedy:  happy house go happy cat wow
# Beam:    happy house dog happy cat wow
# Viterbi: happy house on happy cat wow
#
# TRUTH:   go marvin one up stop
# Greedy:  go bird left stop right
# Beam:    go five left stop right
# Viterbi: happy bird left stop right
#
# TRUTH:   cat on cat no
# Greedy:  house no house up
# Beam:    house no house up
# Viterbi: tree no house up
#
# TRUTH:   go marvin zero down one right stop
# Greedy:  no four zero dog off right stop
# Beam:    no four zero dog off right stop
# Viterbi: go marvin zero dog off right stop
#
# TRUTH:   cat on bird yes
# Greedy:  wow one one wow
# Beam:    wow one nine wow
# Viterbi: go sheila one left
#
# TRUTH:   happy tree on happy cat no
# Greedy:  down yes five down wow go
# Beam:    cat yes five cat wow go
# Viterbi: tree yes five down wow go
#
# TRUTH:   happy bird on happy cat yes
# Greedy:  three bird zero three cat yes
# Beam:    happy bird zero nine cat yes
# Viterbi: happy bird zero happy cat yes
#
# TRUTH:   happy cat on happy tree yes
# Greedy:  happy house dog happy five yes
# Beam:    happy house dog happy bird yes
# Viterbi: happy house dog happy five yes
#
# TRUTH:   happy tree off happy house no
# Greedy:  tree on dog tree house no
# Beam:    tree on off tree house no
# Viterbi: tree on dog tree house no
#
# TRUTH:   happy bird on happy cat wow
# Greedy:  five bird house five cat nine
# Beam:    happy bird wow five cat nine
# Viterbi: happy bird wow five cat nine
#
# TRUTH:   happy house on happy house yes
# Greedy:  seven house nine seven house cat
# Beam:    happy house on happy house cat
# Viterbi: happy house nine happy house cat
#
# TRUTH:   tree on tree wow
# Greedy:  on two on four
# Beam:    left two left four
# Viterbi: go two left four
#
# TRUTH:   go sheila three up stop
# Greedy:  down right nine nine two
# Beam:    dog right five left stop
# Viterbi: go sheila five left stop
#
# TRUTH:   happy house on happy tree wow
# Greedy:  stop house four stop eight stop
# Beam:    happy house left stop eight stop
# Viterbi: happy house down stop eight stop
#
# TRUTH:   go sheila zero left stop
# Greedy:  zero down zero three cat
# Beam:    four down sheila three cat
# Viterbi: happy cat sheila three cat
#
# TRUTH:   go sheila one down stop
# Greedy:  yes happy one four happy
# Beam:    go down one dog happy
# Viterbi: go sheila one on happy
#
# TRUTH:   go sheila two right stop
# Greedy:  wow sheila two house stop
# Beam:    wow sheila two five stop
# Viterbi: go sheila two down stop
#
# TRUTH:   happy tree off happy tree wow
# Greedy:  stop bed house stop bed wow
# Beam:    stop bed house stop bed wow
# Viterbi: go bed house stop bed wow
#
# TRUTH:   happy house on happy tree yes
# Greedy:  stop cat one stop nine house
# Beam:    on cat one stop nine house
# Viterbi: happy cat down stop nine house
#
# TRUTH:   happy house on happy tree no
# Greedy:  marvin five four marvin zero wow
# Beam:    marvin five dog marvin zero wow
# Viterbi: go five four marvin zero wow
#
# TRUTH:   go marvin zero left two down stop
# Greedy:  go left zero bed happy dog stop
# Beam:    go marvin zero bed happy down stop
# Viterbi: go marvin zero bed happy dog stop
#
# TRUTH:   go sheila three left four down stop
# Greedy:  go five tree zero four dog cat
# Beam:    go eight tree down four dog cat
# Viterbi: go five tree sheila four dog cat
#
# TRUTH:   go sheila four up zero right stop
# Greedy:  right zero wow up two left stop
# Beam:    happy cat wow sheila two left stop
# Viterbi: happy cat wow up two left stop
#
# TRUTH:   go sheila one right five up two up stop
# Greedy:  four four one one nine up two up zero
# Beam:    wow four sheila one wow up two up zero
# Viterbi: go sheila one one nine up two up zero
#
# TRUTH:   go marvin zero right stop
# Greedy:  down bird down bird stop
# Beam:    happy bird zero left stop
# Viterbi: happy bird five left stop
#
# TRUTH:   happy house on happy house wow
# Greedy:  one house four one house wow
# Beam:    happy house up one bird wow
# Viterbi: happy house sheila one house wow
#
# TRUTH:   go sheila one left one down stop
# Greedy:  one sheila wow off on down stop
# Beam:    go sheila one left one down stop
# Viterbi: go sheila one left four down stop
#
# TRUTH:   go sheila one right two left three right stop
# Greedy:  go three four on two off wow on cat
# Beam:    go sheila four right two up stop on cat
# Viterbi: go three four left two up stop on cat
#
# TRUTH:   house on house yes
# Greedy:  happy cat happy house
# Beam:    happy cat happy house
# Viterbi: happy cat happy house
#
# TRUTH:   happy cat on happy house yes
# Greedy:  two go four two wow yes
# Beam:    stop go four two wow yes
# Viterbi: go sheila four two wow yes
#
# TRUTH:   go marvin one left zero up stop
# Greedy:  cat marvin one left zero cat down
# Beam:    cat sheila one left zero stop down
# Viterbi: go marvin one left zero down down
#
# TRUTH:   happy tree on happy bird yes
# Greedy:  happy nine eight happy four yes
# Beam:    happy bed eight wow four yes
# Viterbi: go nine eight happy four yes
#
# TRUTH:   happy cat on happy house wow
# Greedy:  two tree five two dog wow
# Beam:    happy tree sheila two house wow
# Viterbi: happy tree five two dog wow
#
# TRUTH:   happy bird on happy house no
# Greedy:  two zero one two stop dog
# Beam:    no zero one left stop dog
# Viterbi: go sheila one left stop dog
#
# TRUTH:   cat on cat yes
# Greedy:  cat eight cat yes
# Beam:    cat happy cat yes
# Viterbi: go eight cat yes
#
# TRUTH:   go marvin three right stop
# Greedy:  go wow three nine stop
# Beam:    go marvin three right stop
# Viterbi: go marvin three right stop
#
# TRUTH:   go sheila zero left stop
# Greedy:  dog stop zero stop stop
# Beam:    down stop zero down stop
# Viterbi: go sheila zero left stop
#
# TRUTH:   tree on cat wow
# Greedy:  up nine left go
# Beam:    stop nine left go
# Viterbi: go nine left go
#
# TRUTH:   happy tree on happy bird wow
# Greedy:  down happy stop down one go
# Beam:    happy down stop down one go
# Viterbi: go down stop down one go
#
# TRUTH:   happy cat on happy cat yes
# Greedy:  tree cat wow tree cat three
# Beam:    happy cat wow happy cat no
# Viterbi: happy cat wow tree cat no
#
# TRUTH:   go sheila two right stop
# Greedy:  four zero two house house
# Beam:    sheila zero two off house
# Viterbi: go sheila two happy house
#
# TRUTH:   go marvin two down zero left four right stop
# Greedy:  down nine marvin go stop five stop five zero
# Beam:    go marvin two down stop right stop marvin zero
# Viterbi: go nine nine down stop five stop five zero
#
# TRUTH:   go sheila one right two left one left two left stop
# Greedy:  two four cat dog eight four one left four left wow
# Beam:    five four cat cat on sheila one left four left wow
# Viterbi: go happy cat dog eight four one left four left wow
#
# TRUTH:   go sheila four right stop
# Greedy:  happy sheila four left four
# Beam:    go sheila four left four
# Viterbi: go sheila four left four
#
# TRUTH:   go marvin zero up stop
# Greedy:  go eight stop cat stop
# Beam:    go right stop left stop
# Viterbi: go eight four up stop
#
# TRUTH:   happy tree on happy tree yes
# Greedy:  happy nine three happy nine yes
# Beam:    happy right three on happy yes
# Viterbi: go nine three happy nine yes
#
# TRUTH:   happy tree on happy bird wow
# Greedy:  wow down dog wow four wow
# Beam:    five down cat wow four wow
# Viterbi: go down stop wow four wow
#
# TRUTH:   go marvin four left stop
# Greedy:  two four four up go
# Beam:    sheila four one up stop
# Viterbi: go four four up stop
#
# TRUTH:   tree on tree wow
# Greedy:  wow nine wow dog
# Beam:    wow nine wow dog
# Viterbi: go nine wow dog
#
# TRUTH:   happy house off happy tree wow
# Greedy:  eight yes four eight yes dog
# Beam:    tree yes four tree yes dog
# Viterbi: tree yes four tree yes dog
#
# TRUTH:   cat on bird wow
# Greedy:  left up seven wow
# Beam:    eight up stop wow
# Viterbi: go no seven wow
#
# TRUTH:   go sheila three left stop
# Greedy:  happy four five left stop
# Beam:    happy stop five left stop
# Viterbi: go four five left stop
#
# TRUTH:   tree on bird no
# Greedy:  tree nine stop cat
# Beam:    tree right stop cat
# Viterbi: go nine stop cat
#
# TRUTH:   go marvin one right stop
# Greedy:  two one one five zero
# Beam:    two left one sheila zero
# Viterbi: go sheila one five zero
#
# TRUTH:   happy cat on happy tree no
# Greedy:  stop eight off stop nine go
# Beam:    stop eight off stop nine go
# Viterbi: tree yes off stop nine go
#
# TRUTH:   happy tree on happy cat no
# Greedy:  stop three dog stop no no
# Beam:    down three up stop no no
# Viterbi: go three dog stop no no
#
# TRUTH:   go sheila zero left two right stop
# Greedy:  left sheila wow left four wow up
# Beam:    yes sheila wow left four wow up
# Viterbi: go sheila wow left four wow up
#
# TRUTH:   happy cat on happy cat yes
# Greedy:  happy cat bed happy cat left
# Beam:    happy cat on happy cat left
# Viterbi: happy cat bed happy cat left
#
# TRUTH:   cat on cat wow
# Greedy:  cat nine cat wow
# Beam:    cat stop cat wow
# Viterbi: go nine cat wow
#
# TRUTH:   go sheila zero right one right one right stop
# Greedy:  go cat zero right left house bed house stop
# Beam:    go sheila zero right one right one right stop
# Viterbi: happy cat zero right one right one right stop
#
# TRUTH:   tree on bird no
# Greedy:  tree cat four four
# Beam:    happy cat sheila four
# Viterbi: happy cat four four
#
# TRUTH:   go sheila zero right two left three down stop
# Greedy:  go cat zero five dog wow three down stop
# Beam:    go sheila zero five dog wow three down stop
# Viterbi: happy cat zero five dog wow three down stop
#
# TRUTH:   go marvin three up two up stop
# Greedy:  go nine cat left tree cat cat
# Beam:    go nine cat off tree stop cat
# Viterbi: go nine cat happy tree happy cat
#
# TRUTH:   go sheila zero left stop
# Greedy:  cat sheila zero left stop
# Beam:    cat marvin zero left stop
# Viterbi: go sheila zero left stop
#
# TRUTH:   go marvin one down stop
# Greedy:  go four one dog zero
# Beam:    go sheila one marvin zero
# Viterbi: go sheila one down zero
#
# TRUTH:   go marvin four up stop
# Greedy:  no nine stop house zero
# Beam:    no nine four up zero
# Viterbi: go marvin four up zero
#
# TRUTH:   happy tree on happy cat wow
# Greedy:  happy three wow happy stop up
# Beam:    happy tree wow happy zero up
# Viterbi: go tree wow happy stop up
#
# TRUTH:   tree off tree yes
# Greedy:  bed four bed wow
# Beam:    bed four bird wow
# Viterbi: go four bed wow
#
# TRUTH:   happy house on happy cat wow
# Greedy:  happy cat happy happy left sheila
# Beam:    happy cat on happy stop sheila
# Viterbi: happy cat on happy go sheila
#
# TRUTH:   go marvin three left three right stop
# Greedy:  go left tree stop tree wow cat
# Beam:    go nine tree stop tree wow cat
# Viterbi: go happy tree stop tree wow cat
#
# TRUTH:   bird on house wow
# Greedy:  cat one house dog
# Beam:    cat on house dog
# Viterbi: tree on house dog
#
# TRUTH:   go marvin one up zero left three up stop
# Greedy:  go marvin one wow zero four right no stop
# Beam:    go marvin one sheila zero four right down stop
# Viterbi: go marvin one wow zero four right no stop
#
# TRUTH:   go sheila two right stop
# Greedy:  wow sheila down five stop
# Beam:    go sheila sheila five stop
# Viterbi: go sheila down five stop
#
# TRUTH:   happy bird on happy cat no
# Greedy:  up two right up up four
# Beam:    up two right four up four
# Viterbi: go two right four up four
#
# TRUTH:   house on cat no
# Greedy:  three five stop no
# Beam:    house right stop no
# Viterbi: go five stop no
#
# TRUTH:   happy tree on happy house yes
# Greedy:  happy three one happy up house
# Beam:    happy five one happy cat yes
# Viterbi: happy tree on happy cat yes
#
# TRUTH:   cat on house no
# Greedy:  cat down house down
# Beam:    cat wow house down
# Viterbi: go happy house down
#
# TRUTH:   go sheila zero up one left four down two right stop
# Greedy:  go two two stop one left wow wow two nine stop
# Beam:    go sheila two up one left wow wow two nine stop
# Viterbi: go sheila two up one left wow wow two nine stop
#
# TRUTH:   happy cat on happy tree no
# Greedy:  seven cat three seven yes house
# Beam:    happy cat off seven yes house
# Viterbi: happy cat three seven yes house
#
# TRUTH:   happy cat on happy tree no
# Greedy:  happy up three happy four four
# Beam:    happy sheila three up four four
# Viterbi: go up three happy four four
#
# TRUTH:   happy tree on happy house yes
# Greedy:  three four stop three house yes
# Beam:    tree dog stop three house yes
# Viterbi: go down stop three house yes
#
# TRUTH:   go sheila two left stop
# Greedy:  go tree four four down
# Beam:    go sheila four four down
# Viterbi: happy tree four four down
#
# TRUTH:   cat on bird no
# Greedy:  cat cat down go
# Beam:    cat five down go
# Viterbi: happy cat down go
#
# TRUTH:   bird on cat yes
# Greedy:  no four one left
# Beam:    no four one left
# Viterbi: tree wow one left
#
# TRUTH:   go sheila one down stop
# Greedy:  five cat zero house four
# Beam:    on cat on house on
# Viterbi: happy cat on house on
#
# TRUTH:   go sheila one up stop
# Greedy:  wow stop one wow on
# Beam:    down stop one house on
# Viterbi: happy cat tree wow on
#
# TRUTH:   happy bird on happy bird yes
# Greedy:  up zero wow up zero house
# Beam:    up zero wow up zero house
# Viterbi: happy bird wow up zero house
#
# TRUTH:   go marvin three up stop
# Greedy:  dog down cat no down
# Beam:    on happy cat no down
# Viterbi: go happy cat no down
#
# TRUTH:   go marvin three right stop
# Greedy:  no down eight one stop
# Beam:    no down eight left stop
# Viterbi: go down eight one stop
#
# TRUTH:   go marvin zero down four down stop
# Greedy:  bed five zero wow no wow stop
# Beam:    go marvin zero wow no wow stop
# Viterbi: go five zero wow no wow stop
#
# TRUTH:   tree on tree no
# Greedy:  cat five cat four
# Beam:    cat on cat four
# Viterbi: go five nine four
#
# TRUTH:   happy cat on happy cat no
# Greedy:  happy stop five happy stop left
# Beam:    happy stop five down stop left
# Viterbi: go stop five down stop left
#
# TRUTH:   tree on house no
# Greedy:  nine up house zero
# Beam:    one up sheila zero
# Viterbi: go happy house zero
#
# TRUTH:   go marvin one right stop
# Greedy:  go marvin one nine stop
# Beam:    go marvin one right stop
# Viterbi: go marvin one nine stop
#
# TRUTH:   go sheila two right zero right stop
# Greedy:  go sheila stop dog zero dog stop
# Beam:    go sheila stop marvin zero down stop
# Viterbi: go sheila stop down zero down stop
#
# TRUTH:   go sheila zero left one down stop
# Greedy:  down four no left four dog stop
# Beam:    go sheila no left dog dog stop
# Viterbi: go sheila no left four dog stop
#
# TRUTH:   happy cat on happy cat yes
# Greedy:  happy cat two happy cat yes
# Beam:    happy cat on happy cat yes
# Viterbi: happy cat on happy cat yes
#
# TRUTH:   go marvin five left two left stop
# Greedy:  bed bird five nine tree left stop
# Beam:    bed bird five nine tree left stop
# Viterbi: happy bird five nine two left stop
#
# TRUTH:   happy tree on happy cat wow
# Greedy:  happy tree five happy dog marvin
# Beam:    happy tree on happy dog marvin
# Viterbi: happy tree on happy dog marvin
#
# TRUTH:   house on house no
# Greedy:  up one up four
# Beam:    up one up four
# Viterbi: go one up four
#
# TRUTH:   happy tree on happy tree wow
# Greedy:  five happy left five happy stop
# Beam:    on happy cat on happy stop
# Viterbi: go happy cat on happy stop
#
# TRUTH:   go sheila three left stop
# Greedy:  cat stop on down yes
# Beam:    down stop five down stop
# Viterbi: go stop on bird yes
#
# TRUTH:   happy house on happy bird wow
# Greedy:  happy house nine happy up left
# Beam:    happy house on happy dog left
# Viterbi: happy house nine happy five left
#
# TRUTH:   happy tree on happy tree no
# Greedy:  happy happy two happy happy four
# Beam:    happy down two seven happy four
# Viterbi: go marvin two on happy four
#
# TRUTH:   cat on tree wow
# Greedy:  cat down stop wow
# Beam:    nine down stop wow
# Viterbi: go down stop wow
#
# TRUTH:   happy tree on happy house yes
# Greedy:  five five five five house yes
# Beam:    happy sheila five happy house yes
# Viterbi: go five five happy house yes
#
# TRUTH:   go sheila one left stop
# Greedy:  up sheila off no stop
# Beam:    go sheila cat no stop
# Viterbi: go sheila off no stop
#
# TRUTH:   happy house off happy house wow
# Greedy:  seven house left seven house stop
# Beam:    tree nine left seven house stop
# Viterbi: happy house left three down stop
#
# TRUTH:   happy cat on happy cat no
# Greedy:  happy tree five happy tree wow
# Beam:    happy tree on happy tree wow
# Viterbi: happy tree on happy tree wow
#
# TRUTH:   happy cat on happy house no
# Greedy:  nine cat cat nine wow four
# Beam:    nine down cat cat wow four
# Viterbi: happy cat yes nine wow four
#
# TRUTH:   happy house on happy tree wow
# Greedy:  happy stop marvin happy two wow
# Beam:    happy go marvin happy cat wow
# Viterbi: go stop stop happy cat wow
#
# TRUTH:   house on tree wow
# Greedy:  cat house tree four
# Beam:    happy house on four
# Viterbi: happy house on four
#
# TRUTH:   tree on cat no
# Greedy:  five on five down
# Beam:    bird on five down
# Viterbi: tree on five down
#
# TRUTH:   go marvin two down stop
# Greedy:  house up zero cat stop
# Beam:    go up zero down stop
# Viterbi: go up zero down stop
#
# TRUTH:   go sheila three up stop
# Greedy:  happy zero wow no zero
# Beam:    happy stop wow down zero
# Viterbi: go tree wow no zero
#
# TRUTH:   tree off tree wow
# Greedy:  bird bed bird no
# Beam:    dog bed bird no
# Viterbi: go bed bird no
#
# TRUTH:   go marvin three up stop
# Greedy:  dog seven eight up four
# Beam:    dog seven eight wow four
# Viterbi: go seven eight wow four
#
# TRUTH:   go marvin two up stop
# Greedy:  four tree four up stop
# Beam:    sheila two two up stop
# Viterbi: happy tree four up stop
#
# TRUTH:   happy house on happy cat wow
# Greedy:  happy five no happy up nine
# Beam:    happy house no five up nine
# Viterbi: go five no happy wow nine
#
# TRUTH:   go marvin two left stop
# Greedy:  no five go left four
# Beam:    no five go marvin four
# Viterbi: go five go left four
#
# TRUTH:   go sheila zero right stop
# Greedy:  down zero down wow stop
# Beam:    down zero down left stop
# Viterbi: go zero down left stop
#
# TRUTH:   go marvin zero left two right stop
# Greedy:  go marvin zero wow two right stop
# Beam:    go marvin zero down two right stop
# Viterbi: go marvin zero wow two right stop
#
# TRUTH:   go marvin one left zero up three left one right stop
# Greedy:  no happy bird cat zero up three house dog house stop
# Beam:    no happy bird left zero up three stop dog left stop
# Viterbi: go happy bird marvin zero up three house dog house stop
#
# TRUTH:   go sheila two up stop
# Greedy:  dog sheila five down stop
# Beam:    dog sheila two down stop
# Viterbi: go sheila five down stop
#
# TRUTH:   go marvin one left stop
# Greedy:  no four nine left stop
# Beam:    no four right left stop
# Viterbi: go four nine left stop
#
# TRUTH:   happy bird on happy cat yes
# Greedy:  happy nine four happy cat cat
# Beam:    happy sheila four happy cat cat
# Viterbi: go nine four happy cat cat
#
# TRUTH:   happy house on happy house yes
# Greedy:  cat house sheila cat house three
# Beam:    cat five sheila stop house three
# Viterbi: happy house sheila five house three
#
# TRUTH:   go marvin four right one up stop
# Greedy:  four cat marvin left nine up down
# Beam:    on cat four left one up down
# Viterbi: happy cat five left nine up down
#
# TRUTH:   go marvin two right one left zero right stop
# Greedy:  no five four five left down stop eight marvin
# Beam:    no five four five left down stop three right
# Viterbi: happy house four five one down stop eight right
#
# TRUTH:   go sheila one left stop
# Greedy:  down four down left five
# Beam:    dog four down yes five
# Viterbi: go four down left five
#
# TRUTH:   go sheila two left one left stop
# Greedy:  go sheila two left one left stop
# Beam:    go sheila two left one left stop
# Viterbi: go sheila two left one left stop
#
# TRUTH:   cat on cat wow
# Greedy:  bed wow bed stop
# Beam:    cat wow down stop
# Viterbi: tree wow bed stop
#
# TRUTH:   go marvin two left one up one down stop
# Greedy:  go go nine left one down one go stop
# Beam:    go no nine left one down one down stop
# Viterbi: cat off nine left one down one down stop
#
# TRUTH:   happy house on happy tree wow
# Greedy:  happy house nine happy five nine
# Beam:    happy house on happy nine nine
# Viterbi: happy house on happy five nine
#
# TRUTH:   go sheila two left two left two right two down stop
# Greedy:  zero sheila two left four left two five two dog stop
# Beam:    go sheila two left two left two marvin two up stop
# Viterbi: go sheila two left four left two five two dog stop
#
# TRUTH:   happy cat on happy cat wow
# Greedy:  down wow stop down wow wow
# Beam:    nine down stop down cat wow
# Viterbi: tree wow stop down wow wow
#
# TRUTH:   go marvin zero up stop
# Greedy:  wow nine zero cat stop
# Beam:    wow nine zero up stop
# Viterbi: go nine zero down stop
#
# TRUTH:   go marvin two left zero up stop
# Greedy:  cat down two left zero cat stop
# Beam:    cat marvin two left zero down stop
# Viterbi: go marvin two left zero up stop
#
# TRUTH:   happy house on happy tree wow
# Greedy:  stop wow four stop tree go
# Beam:    stop wow four on tree no
# Viterbi: tree wow four stop tree no
#
# TRUTH:   happy bird on happy tree yes
# Greedy:  nine four stop nine down yes
# Beam:    dog four stop nine down yes
# Viterbi: go down stop nine down yes
#
# TRUTH:   go marvin three right stop
# Greedy:  no nine stop five up
# Beam:    no nine stop five up
# Viterbi: go nine stop five up
#
# TRUTH:   go sheila one right stop
# Greedy:  house up wow nine stop
# Beam:    five up wow nine stop
# Viterbi: happy cat wow nine stop
#
# TRUTH:   go marvin one up one left one up stop
# Greedy:  two marvin nine wow wow wow nine house stop
# Beam:    go marvin cat wow wow wow nine up stop
# Viterbi: go marvin nine wow wow wow nine house stop
#
# TRUTH:   go sheila one down stop
# Greedy:  cat zero four nine stop
# Beam:    down zero wow nine stop
# Viterbi: go zero four nine stop
#
# TRUTH:   cat on cat no
# Greedy:  three on three four
# Beam:    house on down four
# Viterbi: tree on three four
#
# TRUTH:   go sheila one left one right stop
# Greedy:  go four wow left one four down
# Beam:    go sheila one left one four down
# Viterbi: go sheila one left one four down
#
# TRUTH:   go sheila two left stop
# Greedy:  stop yes down yes zero
# Beam:    stop yes cat yes zero
# Viterbi: tree yes down yes zero
#
# TRUTH:   happy cat on happy bird no
# Greedy:  happy cat happy happy zero no
# Beam:    happy cat happy seven zero no
# Viterbi: happy cat on happy house no
#
# TRUTH:   go marvin zero up zero right zero up stop
# Greedy:  four nine stop up zero right zero down stop
# Beam:    eight nine stop up zero right zero down stop
# Viterbi: go nine stop up zero right zero down stop
#
# TRUTH:   happy cat on happy house no
# Greedy:  cat cat four cat house down
# Beam:    cat sheila four down three down
# Viterbi: happy cat four down four down
#
# TRUTH:   go marvin one left stop
# Greedy:  no nine one left stop
# Beam:    no nine one left stop
# Viterbi: go nine one left stop
#
# TRUTH:   go marvin zero up two left stop
# Greedy:  down marvin sheila down cat left yes
# Beam:    go marvin two down five left yes
# Viterbi: go marvin two down happy cat yes
#
# TRUTH:   house on cat wow
# Greedy:  right on go go
# Beam:    house on dog go
# Viterbi: tree on four go
#
# TRUTH:   happy bird on happy cat yes
# Greedy:  tree marvin cat tree cat yes
# Beam:    tree on happy tree cat yes
# Viterbi: go marvin happy tree cat yes
#
# TRUTH:   go sheila one right four up two right stop
# Greedy:  down sheila one nine four stop down nine stop
# Beam:    go sheila one sheila four stop down nine stop
# Viterbi: go sheila one nine four stop down nine stop
#
# TRUTH:   happy bird on happy cat wow
# Greedy:  right wow stop right cat dog
# Beam:    house left stop off cat dog
# Viterbi: tree wow stop wow cat dog
#
# TRUTH:   happy cat on happy bird no
# Greedy:  happy cat four happy four down
# Beam:    happy cat on happy four down
# Viterbi: happy cat on happy four down
#
# TRUTH:   happy cat on happy tree no
# Greedy:  happy cat go happy happy four
# Beam:    happy cat on happy sheila four
# Viterbi: happy cat on happy sheila four
#
# TRUTH:   happy bird off happy house no
# Greedy:  happy wow stop happy four nine
# Beam:    happy down stop happy sheila one
# Viterbi: tree wow stop happy four nine
#
# TRUTH:   go sheila one left stop
# Greedy:  house zero five happy marvin
# Beam:    house stop five nine marvin
# Viterbi: go zero five go marvin
#
# TRUTH:   go marvin zero right zero up one up one up stop
# Greedy:  four wow zero nine eight happy wow go six happy house
# Beam:    cat wow zero nine eight cat wow go yes happy house
# Viterbi: tree wow zero nine eight happy wow go six happy house
#
# TRUTH:   happy cat on happy tree no
# Greedy:  wow down four wow happy one
# Beam:    nine down four on happy one
# Viterbi: go down four wow happy one
#
# TRUTH:   happy cat on happy bird no
# Greedy:  happy cat cat happy bird wow
# Beam:    happy cat wow happy bird wow
# Viterbi: happy cat wow happy bird wow
#
# TRUTH:   happy tree on happy cat no
# Greedy:  two four go two tree wow
# Beam:    sheila four go yes tree wow
# Viterbi: go four go happy tree wow
#
# TRUTH:   cat on bird wow
# Greedy:  cat happy five wow
# Beam:    cat no five wow
# Viterbi: go dog five wow
#
# TRUTH:   go marvin one left three up two left one right stop
# Greedy:  down left four wow happy up four wow on right stop
# Beam:    go wow four wow five up tree wow one right stop
# Viterbi: go left four wow happy up four wow four right stop
#
# TRUTH:   cat on tree wow
# Greedy:  cat left bird five
# Beam:    cat bed five five
# Viterbi: go marvin five five
#
# TRUTH:   go marvin three right one left one up one right stop
# Greedy:  down marvin three right wow left wow up four five stop
# Beam:    go marvin three right five left one up four right stop
# Viterbi: go marvin three right wow left wow up four five stop
#
# TRUTH:   go marvin two up three right zero up stop
# Greedy:  four up five five eight one off up stop
# Beam:    two up nine five sheila one five up stop
# Viterbi: go up five five eight bird off up stop
#
# TRUTH:   go marvin zero down two left stop
# Greedy:  no off cat go no up three
# Beam:    no off cat bed two up three
# Viterbi: cat off cat marvin two up three
#
# TRUTH:   go marvin zero left stop
# Greedy:  marvin bird zero left cat
# Beam:    one right zero left cat
# Viterbi: happy bird zero left cat
#
# TRUTH:   go sheila one up one up stop
# Greedy:  go four house stop house stop off
# Beam:    go stop house on house cat off
# Viterbi: go four down stop house stop off
#
# TRUTH:   happy cat off happy bird yes
# Greedy:  house cat four house marvin wow
# Beam:    happy cat stop house bird wow
# Viterbi: happy cat four down tree wow
#
# TRUTH:   go sheila three down stop
# Greedy:  go cat three zero up
# Beam:    go sheila three zero up
# Viterbi: happy cat marvin zero up
#
# TRUTH:   cat on cat wow
# Greedy:  cat one cat cat
# Beam:    marvin one happy cat
# Viterbi: tree on cat cat
#
# TRUTH:   house on house no
# Greedy:  five stop five up
# Beam:    dog stop five up
# Viterbi: go stop five up
#
# TRUTH:   go marvin one left stop
# Greedy:  no five nine yes stop
# Beam:    no five nine down stop
# Viterbi: go five nine yes stop
#
# TRUTH:   go sheila four right one left three right stop
# Greedy:  happy four wow right one yes three wow stop
# Beam:    happy cat wow right one sheila three right stop
# Viterbi: go four wow right one left three right stop
#
# TRUTH:   go sheila one down one up stop
# Greedy:  stop sheila wow down left up up
# Beam:    stop sheila wow down wow up stop
# Viterbi: go sheila wow down one up stop
#
# TRUTH:   go marvin one down two right three up zero up stop
# Greedy:  go nine five house two off three happy two dog down
# Beam:    go nine five down two up three sheila two dog down
# Viterbi: go nine five house two left three marvin two dog down

# %% [markdown]
# **Question 2.11**:  Can you implement some backoff strategies to face rare seen words(or sequence of words)?  Can you implement some backoff strategies to face Out of Vocabulary (OOV) words? Does it improve your Word Error Rate?
#
# **Question 2.12**:  How would you optimize jointly an acoustic model and language model?

# %% [markdown]
# # What you are expected to do in this second part
# The second part of the TP above contains the different blocks that allow you to decode sequence of speech commands. You are expected to implement the different decoding algorithms and compare them in WER performance, time and memory costs.
#  There are several question in this part, include your answers in the report. The **grade will not depend on the performance of the final system**, but on how you **experimented, tried different ideas, and comment** on them.

# %% [markdown]
# # Final Report and Notebook
# Write your report in a external PDF file, and send the **commented clean** ipython notebook along your assignment at mva.speech.language@gmail.com with title '[TP1_2020] FirstName_LastName'
#
#
# The report needs to be **succint**. It will include formula, results graphs, and your critical analysis of the experiments. All the questions **need to be answered in the pdf report**. Answers in the notebook will not be taken into account.
#
# Good luck!
#
#
# ---
